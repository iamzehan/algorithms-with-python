# %% [markdown]
# ### **Breadth First Search(BFS) Problem** where you find a mango seller in your friendlist. (Red node is the mango seller)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### The above graph should look like this

# %%
from collections import deque
graph = {}
graph["you"] = ["alice", "bob", "claire"]
graph["bob"] = ["anuj", "peggy"]
graph["alice"] = ["peggy"]
graph["claire"] = ["thom", "johnny M"]
graph["anuj"] = []
graph["peggy"] = []
graph["thom"] = []
graph["johnny M"] = []

# %% [markdown]
# ### Implementing the Breadth First Search Algorithm

# %%
def person_is_seller(person):
    return person[-1] == "M"
def bfs(graph, name):
    search_queue = deque()
    search_queue += graph[name]
    searched = []
    while search_queue:
        print(search_queue)
        person = search_queue.popleft()
        if person not in searched:
            if person_is_seller(person):
                print(person[:-1].title()+"is a Mango seller")
                return True
            else:
                search_queue += graph[person]
                searched.append(person)
        else:
            print(f"{person} is already searched!")
    return False
print(bfs(graph,"you"))
# Out:
# deque(['alice', 'bob', 'claire'])
# deque(['bob', 'claire', 'peggy'])
# deque(['claire', 'peggy', 'anuj', 'peggy'])
# deque(['peggy', 'anuj', 'peggy', 'thom', 'johnny M'])
# deque(['anuj', 'peggy', 'thom', 'johnny M'])
# deque(['peggy', 'thom', 'johnny M'])
# peggy is already searched!
# deque(['thom', 'johnny M'])
# deque(['johnny M'])
# Johnny is a Mango seller
# True
